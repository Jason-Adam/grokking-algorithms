# %%
def g_func(g_info):
    if hr_per_guard <=8:
        shift_time_per_guard = hr_per_guard
        reg_hours = shift_time_per_guard * guard
        ot_hours = (hr_per_guard - shift_time_per_guard) * guard
        reg_pay = reg_hours * 15
        ot_pay = ot_hours * 20
        total_pay = reg_pay + ot_pay
        print("Number of Guards:" + str(guard))
        print("Hours per Guard:" + str(hr_per_guard))
        print("Hours per Shift per Guard:" + str(shift_time_per_guard))
        print("Total Regular Hours Worked:" + str(reg_hours))
        print("Total Overtime Hours Worked:" + str(ot_hours))
        print("Total Regular Pay:" + str(reg_pay))
        print("Total Overtime Pay:" + str(ot_pay))
        print("Total Pay:" + str(total_pay))
        print("---------------------------------")
    elif hr_per_guard >= 8:
        shift_time_per_guard = 8
        reg_hours = shift_time_per_guard * guard
        ot_hours = (hr_per_guard - shift_time_per_guard) * guard
        reg_pay = reg_hours * 15
        ot_pay = ot_hours * 20
        total_pay = reg_pay + ot_pay
        print("Number of Guards:" + str(guard))
        print("Hours per Guard:" + str(hr_per_guard))
        print("Hours per Shift per Guard:" + str(shift_time_per_guard))
        print("Total Regular Hours Worked:" + str(reg_hours))
        print("Total Overtime Hours Worked:" + str(ot_hours))
        print("Total Regular Pay:" + str(reg_pay))
        print("Total Overtime Pay:" + str(ot_pay))
        print("Total Pay:" + str(total_pay))
        print("---------------------------------")
    return(g_info)

# %%
guards = [1, 2, 3, 4, 5, 6]

for guard in guards:
    hr_per_guard = 24/guard
    guard_cost = 0
    reg_hours = 0
    ot_hours = 0
    reg_pay = 0
    ot_pay = 0
    total_pay = 0
    g_func(guard)
# Out:
# Number of Guards:1
# Hours per Guard:24.0
# Hours per Shift per Guard:8
# Total Regular Hours Worked:8
# Total Overtime Hours Worked:16.0
# Total Regular Pay:120
# Total Overtime Pay:320.0
# Total Pay:440.0
# ---------------------------------
# Number of Guards:2
# Hours per Guard:12.0
# Hours per Shift per Guard:8
# Total Regular Hours Worked:16
# Total Overtime Hours Worked:8.0
# Total Regular Pay:240
# Total Overtime Pay:160.0
# Total Pay:400.0
# ---------------------------------
# Number of Guards:3
# Hours per Guard:8.0
# Hours per Shift per Guard:8.0
# Total Regular Hours Worked:24.0
# Total Overtime Hours Worked:0.0
# Total Regular Pay:360.0
# Total Overtime Pay:0.0
# Total Pay:360.0
# ---------------------------------
# Number of Guards:4
# Hours per Guard:6.0
# Hours per Shift per Guard:6.0
# Total Regular Hours Worked:24.0
# Total Overtime Hours Worked:0.0
# Total Regular Pay:360.0
# Total Overtime Pay:0.0
# Total Pay:360.0
# ---------------------------------
# ...
